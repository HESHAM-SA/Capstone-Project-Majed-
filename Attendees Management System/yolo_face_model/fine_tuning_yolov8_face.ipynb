# %%
from roboflow import Roboflow
rf = Roboflow(api_key="PvsFg9JdoAusIC6Iyczc")
project = rf.workspace("attendees").project("face-detections-of-students-02")
version = project.version(2)
dataset = version.download("yolov8")

# %%
# !yolo copy-cfg

# %%
# !yolo cfg=default_copy.yaml
# no forget to write path of data.yaml
# and write abslote path train, test, val
# Out:
# Overriding /root/miniconda3/envs/yolo/lib/python3.10/site-packages/ultralytics/cfg/default.yaml with default_copy.yaml
# New https://pypi.org/project/ultralytics/8.2.22 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.18 🚀 Python-3.10.14 torch-2.3.0 CUDA:0 (NVIDIA GeForce GTX 1050 Ti, 4096MiB)
# ...

# %%
# !yolo detect predict model='D:/heshamsadan/Desktop/SDAIA_BootCamp/Projects/Project07_Aziz_Anwar_Hesham/F_D_api_key01_pretrain_model/runs/detect/train4/weights/best.pt' source='D:/heshamsadan/Desktop/SDAIA_BootCamp/Projects/Project07_Aziz_Anwar_Hesham/video_2min_vanila.mp4'

# %%
# !yolo export model=r'D:\heshamsadan\Desktop\SDAIA_BootCamp\Projects\Project07_Aziz_Anwar_Hesham\F_D_api_key01_pretrain_model\runs\detect\train4\weights\best.pt' format=onnx

# %%
# data - cfg - cfg(argumnt) - yolo train, TensorBord, pred, export
